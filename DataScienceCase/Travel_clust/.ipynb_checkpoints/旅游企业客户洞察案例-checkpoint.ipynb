# %% [markdown]
# 建模分析
# 1、数据集中的变量较多，如果全部进入模型会导致模型解释困难。因此，一方面我们对于有相关性的变量进行降维，减少变量数目；另一方面，基于业务理解，我们预先将变量进行分组，使得同一组的变量能尽量解释业务的一个方面。比如本例中将变量分成三组，分别是家庭基本情况、财务状况和用户爱好，通过对每组变量分别进行聚类，获取用户的侧写，再将三个聚类结果进行综合，以获得较完整的用户画像。
# 2、本例中数据类型复杂，包含了连续变量、无序分类和有序分类变量。由于K-means最好仅用于连续型变量聚类，因此需要对变量进行预处理。对于有序分类变量，如果分类水平较多可以视作连续变量处理，否则视作无序分类变量一样处理，再进入模型；无序分类变量数目较少时，可以使用其哑变量编码进入模型。本例中由于有较多的二分类变量，又集中在用户爱好这一方面，因此我们将interested_reading这一有序分类变量二值化，再与其他几个二分类变量一起进行汇总，得到用户的“爱好广度”，使用“爱好广度”与其他连续型的爱好类变量进行聚类。
# 3、离散变量如HH_has_children一般不参与聚类，因为其本身就可以视作是簇的标签；如果为了后期解释模型时简化处理，在离散变量不多的情况之下，也可以做哑变量变换后进入模型。

# %% [markdown]
# # 1读取数据

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
travel = pd.read_csv('data_travel.csv')
travel.head()
# Out:
#    interested_travel  computer_owner  age  home_value  loan_ratio  risk_score  \
# 0                NaN             NaN   64      124035          73         932
# 1                0.0             1.0   69      138574          73        1000
# 2                0.0             0.0   57      148136          77         688
# 3                1.0             1.0   80      162532          74         932
# 4                1.0             1.0   48      133580          77         987
#
#    marital  interested_sport  HH_grandparent  HH_dieting  HH_head_age  \
# 0        3               312             420         149           96
# 1        7               241             711         263           68
# 2        1               367             240         240           56
# 3        7               291             832         197           86
# 4       10               137             121         209           42
#
#    auto_member  interested_golf  interested_gambling HH_has_children  \
# 0          626                0                    0             NaN
# 1          658                0                    0               N
# 2          354                0                    1               N
# 3          462                1                    1               Y
# 4          423                0                    1               Y
#
#    HH_adults_num interested_reading
# 0            NaN                  0
# 1            5.0                  3
# 2            2.0                  1
# 3            2.0                  3
# 4            3.0                  3

# %%
travel.describe(include = 'all').T
# Out:
#                       count unique  top    freq      mean       std    min  \
# interested_travel    149788    NaN  NaN     NaN  0.427745  0.494753      0
# computer_owner       149788    NaN  NaN     NaN  0.856571  0.350511      0
# age                  167177    NaN  NaN     NaN   59.5071   14.3117     18
# home_value           167177    NaN  NaN     NaN    207621    107823  48910
# loan_ratio           167177    NaN  NaN     NaN   66.7627   9.75183      0
# risk_score           167177    NaN  NaN     NaN   817.032    165.49      1
# marital              167177    NaN  NaN     NaN   6.88402   2.61055      1
# interested_sport     167177    NaN  NaN     NaN   259.432   78.8675     60
# HH_grandparent       167177    NaN  NaN     NaN   377.072   248.045      0
# HH_dieting           167177    NaN  NaN     NaN   204.593    78.971     47
# HH_head_age          167177    NaN  NaN     NaN    59.368   16.7129     18
# auto_member          167177    NaN  NaN     NaN   486.861   151.167     49
# interested_golf      167177    NaN  NaN     NaN  0.373012  0.483607      0
# interested_gambling  167177    NaN  NaN     NaN  0.357842  0.479367      0
# HH_has_children      159899      2    N  111462       NaN       NaN    NaN
# HH_adults_num        145906    NaN  NaN     NaN   2.77083   1.28542      0
# interested_reading   167177      5    3   65096       NaN       NaN    NaN
#
#                         25%     50%     75%    max
# interested_travel         0       0       1      1
# computer_owner            1       1       1      1
# age                      49      59      70     99
# home_value           135595  182106  248277  1e+06
# loan_ratio               63      69      73    102
# risk_score              748     844     945   1000
# marital                   5       7       9     10
# interested_sport        204     251     306    920
# HH_grandparent          182     351     528    980
# HH_dieting              144     185     252    633
# HH_head_age              48      60      71     99
# auto_member             377     492     600    878
# interested_golf           0       0       1      1
# interested_gambling       0       0       1      1
# HH_has_children         NaN     NaN     NaN    NaN
# HH_adults_num             2       2       4      7
# interested_reading      NaN     NaN     NaN    NaN

# %%
travel.dtypes
# Out:
# interested_travel      float64
# computer_owner         float64
# age                      int64
# home_value               int64
# loan_ratio               int64
# risk_score               int64
# marital                  int64
# interested_sport         int64
# HH_grandparent           int64
# HH_dieting               int64
# HH_head_age              int64
# auto_member              int64
# interested_golf          int64
# interested_gambling      int64
# HH_has_children         object
# HH_adults_num          float64
# interested_reading      object
# dtype: object

# %% [markdown]
# # 2数据预处理

# %%
#填补缺失值
fill_cols = ['interested_travel','computer_owner','HH_adults_num']
fill_values = {col:travel[col].mode()[0] for col in fill_cols}

travel = travel.fillna(fill_values)

# %%
#修正错误值
travel['interested_reading'].value_counts()
# Out:
# 3    65096
# 1    43832
# 0    32919
# 2    24488
# .      842
# Name: interested_reading, dtype: int64

# %%
travel['HH_has_children'] = travel['HH_has_children'].replace({'N':0,'Y':1,np.NaN:0})
travel['interested_reading'] = travel['interested_reading'].replace({'.':0}).astype('int')

# %%
#离散变量的相关性-用卡方检验判断
_cols = ['interested_travel','computer_owner','interested_golf','interested_gambling','HH_has_children','interested_reading','marital']
sample = travel[_cols].sample(3000,random_state = 12345)

from itertools import combinations
from scipy import stats

for colA,colB in combinations(_cols,2):
    crosstab = pd.crosstab(sample[colA],sample[colB])
    pval = stats.chi2_contingency(crosstab)[1]
    if pval >0.05:
        print('p_value = %0.3f between "%s" and "%s" ' % (pval,colA,colB))
# Out:
# p_value = 0.710 between "interested_travel" and "HH_has_children"
# p_value = 0.495 between "computer_owner" and "HH_has_children"
# p_value = 0.272 between "interested_golf" and "HH_has_children"

# %% [markdown]
# 结果显示，除了HH_has_children与interested_travel，computer_owner，interested_golf有较大概率是独立的外，其他变量都可以认为是相关的。我们需要整合这些相关的离散变量。

# %%
#对离散变量进行处理

#用户爱好整合成健康类爱好，奢侈型爱好和休闲娱乐爱好。

#为了整合休闲娱乐爱好指标，先对interested_reading进行二值化
from sklearn.preprocessing import Binarizer

binarizer = Binarizer(threshold=1.5)
travel['interested_reading'] = binarizer.fit_transform(
    travel[['interested_reading']])

# %%
#将旅行，电脑，高尔夫，博彩，阅读这些变量进行加总，生成休闲娱乐爱好指标
interest = ['interested_travel','computer_owner','interested_golf',
            'interested_gambling','interested_reading']
n_ = len(interest)

travel = travel.drop(interest, axis=1).assign(interest=travel[interest].sum(axis=1) / n_)
travel
# Out:
#         age  home_value  loan_ratio  risk_score  marital  interested_sport  \
# 0        64      124035          73         932        3               312
# 1        69      138574          73        1000        7               241
# 2        57      148136          77         688        1               367
# 3        80      162532          74         932        7               291
# 4        48      133580          77         987       10               137
# ...     ...         ...         ...         ...      ...               ...
# 167172   46      324020          59         885       10               249
# 167173   51      316241          72         874        4               194
# 167174   43      259207          76        1000        8               209
# 167175   56      165435          65         932       10               289
# 167176   53      283431          63         802        3               221
#
#         HH_grandparent  HH_dieting  HH_head_age  auto_member  HH_has_children  \
# 0                  420         149           96          626                0
# 1                  711         263           68          658                0
# 2                  240         240           56          354                0
# 3                  832         197           86          462                1
# 4                  121         209           42          423                1
# ...                ...         ...          ...          ...              ...
# 167172              40         218           45          575                1
# 167173             183         118           51          531                0
# 167174             172         195           42          318                1
# 167175              83         331           59          458                1
# 167176             344         121           53          231                0
#
#         HH_adults_num  interest
# 0                 2.0       0.2
# 1                 5.0       0.4
# 2                 2.0       0.2
# 3                 2.0       1.0
# 4                 3.0       0.8
# ...               ...       ...
# 167172            2.0       0.4
# 167173            2.0       0.2
# 167174            1.0       0.2
# 167175            6.0       0.8
# 167176            2.0       0.2
#
# [167177 rows x 13 columns]

# %% [markdown]
# 正态化标准化
#
# 1 对不同类型变量执行不同处理，连续变量、有序分类变量及无序分类变量在处理上均有不同，因此先按类型对变量分组，不同组采用不同的处理策略
# 2 如果一个连续变量的可能取值很少，如marital（10个水平）、interest（5个水平）、HH_adults_num（8个水平）等，当将其作为普通连续变量一样进行分布转换，可能生成一些离群值（例如对marital使用scikit-learn进行正态转换，会发现1和10对应的数据点离开均值达到5个标准差）。因此本例中将这几个连续变量作为有序分类变量对待，但不进行分布转化，仅做标准化处理。

# %%
continuous_cols = ['age', 'home_value', 'risk_score', 'interested_sport', 
                   'HH_dieting', 'auto_member', 'HH_grandparent',
                   'HH_head_age', 'loan_ratio']

categorical_cols = ['marital', 'interest', 'HH_adults_num']

discreate_cols = ['HH_has_children']

# %% [markdown]
# 为了聚类后的簇大小比较接近，对于偏态严重的连续变量应转换其分布，令其接近正态分布或均匀分布

# %%
#对连续变量正态化
travel[continuous_cols].hist(bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a29ce29d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120b61a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120ba3e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x120bd6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c16e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c4bb10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124642fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124677b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124681710>]],
#       dtype=object)

# %%
from sklearn.preprocessing import QuantileTransformer

qt = QuantileTransformer(n_quantiles=100, output_distribution='normal')
qt_data = qt.fit_transform(travel[continuous_cols])

pd.DataFrame(qt_data, columns=continuous_cols).hist(bins=25)
plt.show()

# %% [markdown]
# #对有多个水平的有序分类变量进行标准化
# #如前所述，尽管HH_adults_num、marital和interest属于连续变量，但都仅有不到10个水平，因此与有序分类变量一样，仅做标准化

# %%
from sklearn.preprocessing import scale

scale_data = scale(travel[categorical_cols])

# %%
#对二分类变量不做处理，合并各类型的变量
data = np.hstack([qt_data, scale_data, travel[discreate_cols]])
data = pd.DataFrame(
    data, columns=continuous_cols + categorical_cols + discreate_cols)

# %%
data.head()
# Out:
#         age  home_value  risk_score  interested_sport  HH_dieting  \
# 0  0.321971   -0.894356    0.589456          0.742289   -0.515705
# 1  0.619855   -0.627915    5.199338         -0.139710    0.822532
# 2 -0.126937   -0.467029   -0.931654          1.324958    0.525369
# 3  1.335178   -0.254267    0.589456          0.501298    0.114185
# 4 -0.747859   -0.713305    1.144237         -1.807354    0.225553
#
#    auto_member  HH_grandparent  HH_head_age  loan_ratio   marital  interest  \
# 0     0.841621        0.265318     2.572352    0.698526 -1.487818 -1.035281
# 1     1.067571        1.180907     0.458679    0.698526  0.044429 -0.354828
# 2    -0.814106       -0.446657    -0.229884    1.549706 -2.253942 -1.035281
# 3    -0.178175        1.407189     1.639976    0.927754  0.044429  1.686529
# 4    -0.408607       -0.934263    -0.987837    1.549706  1.193615  1.006077
#
#    HH_adults_num  HH_has_children
# 0      -0.547836              0.0
# 1       1.895118              0.0
# 2      -0.547836              0.0
# 3      -0.547836              1.0
# 4       0.266482              1.0

# %% [markdown]
# 5连续变量筛选
# 强相关的连续变量可能会造成结果过于注重某方面的信息

# %%
data.corr()
# Out:
#                        age  home_value  risk_score  interested_sport  \
# age               1.000000   -0.133161    0.267277          0.160400
# home_value       -0.133161    1.000000    0.078683          0.399848
# risk_score        0.267277    0.078683    1.000000          0.227216
# interested_sport  0.160400    0.399848    0.227216          1.000000
# HH_dieting       -0.055680    0.073214   -0.010396          0.510833
# auto_member       0.350650    0.449959    0.228694          0.458832
# HH_grandparent    0.556856   -0.346519    0.105502          0.003389
# HH_head_age       0.618128   -0.146194    0.204181          0.068917
# loan_ratio       -0.227157   -0.412744   -0.143288         -0.278459
# marital          -0.018586    0.315703   -0.004189          0.046471
# interest          0.255992    0.024206    0.063692          0.219913
# HH_adults_num     0.119664    0.087005    0.015897          0.067910
# HH_has_children  -0.403414    0.129105   -0.114419         -0.042624
#
#                   HH_dieting  auto_member  HH_grandparent  HH_head_age  \
# age                -0.055680     0.350650        0.556856     0.618128
# home_value          0.073214     0.449959       -0.346519    -0.146194
# risk_score         -0.010396     0.228694        0.105502     0.204181
# interested_sport    0.510833     0.458832        0.003389     0.068917
# HH_dieting          1.000000     0.134335       -0.011991    -0.205443
# auto_member         0.134335     1.000000        0.144387     0.259093
# HH_grandparent     -0.011991     0.144387        1.000000     0.564314
# HH_head_age        -0.205443     0.259093        0.564314     1.000000
# loan_ratio         -0.050179    -0.436346       -0.052227    -0.101310
# marital            -0.052736     0.274864       -0.182669    -0.151133
# interest            0.246872     0.316888        0.232228     0.065522
# HH_adults_num       0.073091     0.160848        0.040185     0.003645
# HH_has_children     0.099312    -0.142703       -0.395548    -0.333566
#
#                   loan_ratio   marital  interest  HH_adults_num  \
# age                -0.227157 -0.018586  0.255992       0.119664
# home_value         -0.412744  0.315703  0.024206       0.087005
# risk_score         -0.143288 -0.004189  0.063692       0.015897
# interested_sport   -0.278459  0.046471  0.219913       0.067910
# HH_dieting         -0.050179 -0.052736  0.246872       0.073091
# auto_member        -0.436346  0.274864  0.316888       0.160848
# HH_grandparent     -0.052227 -0.182669  0.232228       0.040185
# HH_head_age        -0.101310 -0.151133  0.065522       0.003645
# loan_ratio          1.000000 -0.223850 -0.157724      -0.178494
# marital            -0.223850  1.000000  0.247610       0.469695
# interest           -0.157724  0.247610  1.000000       0.207927
# HH_adults_num      -0.178494  0.469695  0.207927       1.000000
# HH_has_children     0.035962  0.376839  0.015622       0.038965
#
#                   HH_has_children
# age                     -0.403414
# home_value               0.129105
# risk_score              -0.114419
# interested_sport        -0.042624
# HH_dieting               0.099312
# auto_member             -0.142703
# HH_grandparent          -0.395548
# HH_head_age             -0.333566
# loan_ratio               0.035962
# marital                  0.376839
# interest                 0.015622
# HH_adults_num            0.038965
# HH_has_children          1.000000

# %% [markdown]
# 如果以0.6作为相关系数的上限。在相关系数矩阵中,发现'age'和 'HH_head_age'的相关系数超过0.6，因此决定, 'HH_head_age'不参与聚类运算.

# %% [markdown]
# 对不同维度的数据分别建模并选择K值

# %%
household = ['age', 'marital', 'HH_adults_num', 'HH_has_children','HH_grandparent']
finance = ['home_value', 'risk_score', 'loan_ratio']
hobby = ['HH_dieting', 'auto_member', 'interest', 'interested_sport']

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

def cluster_plot(data, k_range=range(2, 12), n_init=5, sample_size=2000, 
                 n_jobs=-1):
    scores = []
    for k in k_range:
        kmeans = KMeans(n_clusters=k, n_init=n_init, n_jobs=n_jobs)
        kmeans.fit(data)
        sil = silhouette_score(data, kmeans.labels_, 
                               sample_size=sample_size)
        scores.append([k, kmeans.inertia_, sil])

    scores_df = pd.DataFrame(scores, columns=['k','sum_square_dist', 'sil'])
    plt.figure(figsize=[9, 2])
    plt.subplot(121, ylabel='sum_square')
    plt.plot(scores_df.k, scores_df.sum_square_dist)
    plt.subplot(122, ylabel='silhouette_score')
    plt.plot(scores_df.k, scores_df.sil)
    plt.show()

# %%
cluster_plot(data[household])
#结果可以得到k = 4是比较好的选择

# %%
cluster_plot(data[finance])
#k = 2是比较好的选择

# %%
cluster_plot(data[hobby])
#k = 2是比较好的选择

# %% [markdown]
# 选择适当K值分别对三个维度聚类，并将相应标签连接至原始数据集

# %%
def k_means(data, k=2, n_init=5, n_jobs=-1):
    model = KMeans(n_clusters=k, n_init=n_init, n_jobs=n_jobs)
    model.fit(data)
    return model.labels_

# %%
household_labels = k_means(data[household], k=4)
finance_labels = k_means(data[finance], k=2)
hobby_labels = k_means(data[hobby], k=2)

label_names = ['HH', 'finance', 'hobby']
labels = np.vstack([household_labels, finance_labels, hobby_labels]).T
travel_labels = travel.join(pd.DataFrame(labels, columns=label_names))

# %% [markdown]
# 对各个簇的特征进行描述——使用原始数据

# %%
travel_labels
# Out:
#         age  home_value  loan_ratio  risk_score  marital  interested_sport  \
# 0        64      124035          73         932        3               312
# 1        69      138574          73        1000        7               241
# 2        57      148136          77         688        1               367
# 3        80      162532          74         932        7               291
# 4        48      133580          77         987       10               137
# ...     ...         ...         ...         ...      ...               ...
# 167172   46      324020          59         885       10               249
# 167173   51      316241          72         874        4               194
# 167174   43      259207          76        1000        8               209
# 167175   56      165435          65         932       10               289
# 167176   53      283431          63         802        3               221
#
#         HH_grandparent  HH_dieting  HH_head_age  auto_member  HH_has_children  \
# 0                  420         149           96          626                0
# 1                  711         263           68          658                0
# 2                  240         240           56          354                0
# 3                  832         197           86          462                1
# 4                  121         209           42          423                1
# ...                ...         ...          ...          ...              ...
# 167172              40         218           45          575                1
# 167173             183         118           51          531                0
# 167174             172         195           42          318                1
# 167175              83         331           59          458                1
# 167176             344         121           53          231                0
#
#         HH_adults_num  interest  HH  finance  hobby
# 0                 2.0       0.2   0        0      0
# 1                 5.0       0.4   2        1      0
# 2                 2.0       0.2   0        0      0
# 3                 2.0       1.0   1        0      0
# 4                 3.0       0.8   3        0      1
# ...               ...       ...  ..      ...    ...
# 167172            2.0       0.4   3        0      0
# 167173            2.0       0.2   0        0      1
# 167174            1.0       0.2   3        1      1
# 167175            6.0       0.8   2        0      0
# 167176            2.0       0.2   0        0      1
#
# [167177 rows x 16 columns]

# %%
travel_labels.groupby('hobby')[hobby].mean()
# Out:
#        HH_dieting  auto_member  interest  interested_sport
# hobby
# 0      243.258350   571.119483  0.652133        307.706956
# 1      164.487936   399.464173  0.350943        209.358189

# %%
# 决策树：
from sklearn.tree import DecisionTreeClassifier
clf_hb=DecisionTreeClassifier()
clf_hb.fit(travel_labels[hobby],travel_labels['hobby'])

import pydotplus
from IPython.display import Image
import sklearn.tree as tree
dot_hb=tree.export_graphviz(clf_hb,out_file=None,feature_names=hobby,class_names=['0','1'],max_depth=2,filled=True)
graph_hb=pydotplus.graph_from_dot_data(dot_hb)
Image(graph_hb.create_png())

# %%
travel_labels.groupby('HH')[household].mean()
# Out:
#           age   marital  HH_adults_num  HH_has_children  HH_grandparent
# HH
# 0   52.640106  3.363739       1.767803         0.134601      319.678862
# 1   72.324864  6.734761       2.380036         0.085013      599.634941
# 2   61.766573  8.892337       4.538611         0.297191      380.817554
# 3   47.991313  8.633436       2.353745         0.677722      149.804018

# %%
travel_labels.groupby('finance')[finance].mean()
# Out:
#             home_value   risk_score  loan_ratio
# finance
# 0        208894.552357   795.609348   66.924025
# 1        196746.622018  1000.000000   65.384888

# %% [markdown]
# 其中一个用户群特征为：
# 重点用户群A:
# 标签	                                    特征
# 家庭活跃用户(HH_labels=3)	     年龄较轻，已婚有子女，家庭成员数居中
# 低风险用户(finance_labels=0)	   相对较贵的住宅，风险评估相对较低，具有较低的贷款比例
# 高兴趣度用户(hobby_labels=0)	 爱好广泛，热衷于节食与运动，有较大可能是汽车俱乐部会员

# %% [markdown]
# 可以进行多维汇总分析

# %%
travel_labels.groupby(label_names).mean()
# Out:
#                         age     home_value  loan_ratio   risk_score   marital  \
# HH finance hobby
# 0  0       0      55.403593  217127.189804   67.597442   814.828348  3.454759
#            1      50.388228  167959.380704   71.450521   735.440848  3.362103
#    1       0      61.121481  205678.295556   67.037037  1000.000000  3.186667
#            1      59.248426  169124.152542   70.800000  1000.000000  3.030024
# 1  0       0      72.082917  202914.659279   64.650734   835.545653  6.737241
#            1      70.453160  155649.682705   68.330377   774.325776  6.870011
#    1       0      77.100269  189403.639234   64.056265  1000.000000  6.409976
#            1      76.270612  152894.653438   68.188847  1000.000000  6.539856
# 2  0       0      62.196014  249936.472389   61.588254   835.518416  8.898538
#            1      59.982687  185230.715126   67.522531   777.416750  8.910785
#    1       0      66.207363  242003.911463   60.294035  1000.000000  8.811277
#            1      65.695696  183020.621622   66.119119  1000.000000  8.726727
# 3  0       0      49.769987  283967.303338   63.802173   826.321242  8.804605
#            1      45.988497  212677.170111   70.251873   771.121378  8.475681
#    1       0      52.439621  284694.402526   60.691397  1000.000000  8.756906
#            1      50.377751  223693.268949   68.367971  1000.000000  8.438875
#
#                   interested_sport  HH_grandparent  HH_dieting  HH_head_age  \
# HH finance hobby
# 0  0       0            317.211813      343.027464  272.672498    57.865500
#            1            207.781787      304.831928  175.554398    55.155713
#    1       0            334.640741      376.872593  255.651111    64.394815
#            1            231.946731      336.009685  162.353995    68.248426
# 1  0       0            305.189909      631.754214  241.468316    69.396871
#            1            204.792406      553.049945  149.720455    71.158426
#    1       0            322.640746      634.738999  226.749076    73.591703
#            1            226.166268      534.028053  138.187479    77.186110
# 2  0       0            300.302790      381.986447  241.713101    59.389636
#            1            203.488651      370.063535  162.282140    58.842031
#    1       0            319.089935      419.515377  228.513514    62.213420
#            1            221.523524      405.626627  150.653654    63.916917
# 3  0       0            304.294127      132.297956  237.647814    48.376248
#            1            212.636485      164.348575  170.317455    45.781442
#    1       0            322.710339      155.970797  230.511444    49.700079
#            1            227.387531      181.305623  162.388753    48.215159
#
#                   auto_member  HH_has_children  HH_adults_num  interest
# HH finance hobby
# 0  0       0       518.589165         0.128104       1.740877  0.510102
#            1       343.073206         0.147363       1.776124  0.247569
#    1       0       547.644444         0.074815       1.750370  0.487111
#            1       397.232930         0.057627       1.820339  0.232639
# 1  0       0       586.431442         0.087131       2.446660  0.713001
#            1       443.214357         0.091685       2.296951  0.422273
#    1       0       608.499664         0.066846       2.405778  0.701243
#            1       474.907971         0.062265       2.256244  0.388710
# 2  0       0       584.185118         0.282594       4.544938  0.683667
#            1       435.707753         0.337227       4.531975  0.424901
#    1       0       602.869525         0.230662       4.529357  0.662255
#            1       465.550551         0.231231       4.519520  0.408809
# 3  0       0       553.521811         0.667891       2.423855  0.618722
#            1       391.546752         0.693857       2.291967  0.369605
#    1       0       572.166535         0.620363       2.393054  0.582005
#            1       425.585575         0.585575       2.218826  0.358680
